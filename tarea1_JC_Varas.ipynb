# %% [markdown]
# TAREA N°1 ANÁLISIS DE DATOS

# %% [markdown]
# JUAN CRISTÓBAL VARAS TOMASELLO;
# GEOLOGÍA UNIVERSIDAD DEL DESARROLLO;
# 12-10-2021

# %% [markdown]
# 1. Mostrar y explicar, en 16 gráficos (uno por región), como fue la evolución de la cuarentena (por día)
# 2. Qué dia hubo la mayor cantidad de personas en cuarentena en cada región
# 3. Qué día hubo la mayor cantidad de personas en cuarentena en el país

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
import numpy as np
from statsmodels import robust
# %matplotlib inline
# importar bases de datos

# %%
df1 = pd.read_csv('https://github.com/MinCiencia/Datos-COVID19/blob/master/output/producto1/Covid-19.csv?raw=true', sep=',')
# poblaciones por comuna, util para saber la cantidad de personas en cuarentena por fecha

# %%
df2 = pd.read_csv('https://github.com/MinCiencia/Datos-COVID19/blob/master/input/Paso_a_paso/paso_a_paso.csv?raw=true', sep=',')
# paso a paso, muestra en que fases se encuentra cada comuna en cada fecha

# %%
pob=df1[['Region','Codigo region','Comuna','Codigo comuna','Poblacion']] 
pob=pob.dropna()
pob.head()
# de la tabla de covid19, solo nos interesan los campos region, codigo region, comuna, codigo comuna y POBLACION
# Out:
#                Region  Codigo region         Comuna  Codigo comuna  Poblacion
# 0  Arica y Parinacota             15          Arica        15101.0   247552.0
# 1  Arica y Parinacota             15      Camarones        15102.0     1233.0
# 2  Arica y Parinacota             15  General Lagos        15202.0      810.0
# 3  Arica y Parinacota             15          Putre        15201.0     2515.0
# 5            Tarapacá              1  Alto Hospicio         1107.0   129999.0

# %%
pob['Poblacion']=pob['Poblacion'].astype(int)
pob['Codigo comuna']=pob['Codigo comuna'].astype(int)
# tanto poblacion como codigo comuna son valores float, por lo que deben ser convertidos a integer

# %%
pasos=df2.melt(id_vars=["codigo_region","region_residencia","codigo_comuna","comuna_residencia","zona"], var_name="fecha", value_name="paso")
#pasos1=pasos[(pasos['paso']==1)] 
# lo anterior se habia realizado para solo considerar cuando paso=1, sin embargo, arrojaba un error en los graficos al considerar lineas rectas
# donde deberian haber valores 0 con comunas fuera de cuarentena
pasos1=pasos
# lo que se busca es que las fechas se ordenen por filas, y que solo se tengan en cuenta cuando hubo cuarentena (fase 1)

# %%
pasos1=pasos1.rename(columns={'codigo_comuna':'Codigo comuna'})
# el objetivo es cambiar el nombre del codigo para hacer link con otra tabla de datos

# %%
paspob=pob.merge(pasos1, on='Codigo comuna') 
paspobr=pob.merge(pasos1, on='Codigo comuna')
# union de las tablas

# %%
paspob
# Out:
#                     Region  Codigo region            Comuna  Codigo comuna  \
# 0       Arica y Parinacota             15             Arica          15101
# 1       Arica y Parinacota             15             Arica          15101
# 2       Arica y Parinacota             15             Arica          15101
# 3       Arica y Parinacota             15             Arica          15101
# 4       Arica y Parinacota             15             Arica          15101
# ...                    ...            ...               ...            ...
# 168291          Magallanes             12  Torres del Paine          12402
# 168292          Magallanes             12  Torres del Paine          12402
# 168293          Magallanes             12  Torres del Paine          12402
# 168294          Magallanes             12  Torres del Paine          12402
# 168295          Magallanes             12  Torres del Paine          12402
#
#         Poblacion  codigo_region   region_residencia comuna_residencia  \
# 0          247552             15  Arica y Parinacota             Arica
# 1          247552             15  Arica y Parinacota             Arica
# 2          247552             15  Arica y Parinacota             Arica
# 3          247552             15  Arica y Parinacota             Arica
# 4          247552             15  Arica y Parinacota             Arica
# ...           ...            ...                 ...               ...
# 168291       1021             12          Magallanes  Torres del Paine
# 168292       1021             12          Magallanes  Torres del Paine
# 168293       1021             12          Magallanes  Torres del Paine
# 168294       1021             12          Magallanes  Torres del Paine
# 168295       1021             12          Magallanes  Torres del Paine
#
#           zona       fecha  paso
# 0        Rural  2020-07-28     3
# 1       Urbana  2020-07-28     1
# 2        Rural  2020-07-29     3
# 3       Urbana  2020-07-29     1
# 4        Rural  2020-07-30     3
# ...        ...         ...   ...
# 168291   Total  2021-10-02     4
# 168292   Total  2021-10-03     4
# 168293   Total  2021-10-04     4
# 168294   Total  2021-10-05     4
# 168295   Total  2021-10-06     5
#
# [168296 rows x 11 columns]

# %%
cambio2 = (paspob['paso'] == 2)
paspob['Poblacion'][cambio2] = 0
cambio3 = (paspob['paso'] == 3)
paspob['Poblacion'][cambio3] = 0
cambio4 = (paspob['paso'] == 4)
paspob['Poblacion'][cambio4] = 0
cambio5 = (paspob['paso'] == 5)
paspob['Poblacion'][cambio5] = 0
paspob 
# contabiliza los dias que existen entre fechas de pandemia, de otro modo al hacer el grafico,
# mostraria lineas rectas entre fechas con cuerentena y no tomaria en cuenta los valles sin cuarentena
# Out:
# <ipython-input-10-4c6515310eb7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspob['Poblacion'][cambio2] = 0
# <ipython-input-10-4c6515310eb7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspob['Poblacion'][cambio3] = 0
# <ipython-input-10-4c6515310eb7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspob['Poblacion'][cambio4] = 0
# <ipython-input-10-4c6515310eb7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspob['Poblacion'][cambio5] = 0
#                     Region  Codigo region            Comuna  Codigo comuna  \
# 0       Arica y Parinacota             15             Arica          15101
# 1       Arica y Parinacota             15             Arica          15101
# 2       Arica y Parinacota             15             Arica          15101
# 3       Arica y Parinacota             15             Arica          15101
# 4       Arica y Parinacota             15             Arica          15101
# ...                    ...            ...               ...            ...
# 168291          Magallanes             12  Torres del Paine          12402
# 168292          Magallanes             12  Torres del Paine          12402
# 168293          Magallanes             12  Torres del Paine          12402
# 168294          Magallanes             12  Torres del Paine          12402
# 168295          Magallanes             12  Torres del Paine          12402
#
#         Poblacion  codigo_region   region_residencia comuna_residencia  \
# 0               0             15  Arica y Parinacota             Arica
# 1          247552             15  Arica y Parinacota             Arica
# 2               0             15  Arica y Parinacota             Arica
# 3          247552             15  Arica y Parinacota             Arica
# 4               0             15  Arica y Parinacota             Arica
# ...           ...            ...                 ...               ...
# 168291          0             12          Magallanes  Torres del Paine
# 168292          0             12          Magallanes  Torres del Paine
# 168293          0             12          Magallanes  Torres del Paine
# 168294          0             12          Magallanes  Torres del Paine
# 168295          0             12          Magallanes  Torres del Paine
#
#           zona       fecha  paso
# 0        Rural  2020-07-28     3
# 1       Urbana  2020-07-28     1
# 2        Rural  2020-07-29     3
# 3       Urbana  2020-07-29     1
# 4        Rural  2020-07-30     3
# ...        ...         ...   ...
# 168291   Total  2021-10-02     4
# 168292   Total  2021-10-03     4
# 168293   Total  2021-10-04     4
# 168294   Total  2021-10-05     4
# 168295   Total  2021-10-06     5
#
# [168296 rows x 11 columns]

# %%
cambior2 = (paspobr['paso'] == 2)
paspobr['Poblacion'][cambior2] = 0
cambior3 = (paspobr['paso'] == 3)
paspobr['Poblacion'][cambior3] = 0
cambior4 = (paspobr['paso'] == 4)
paspobr['Poblacion'][cambior4] = 0
cambior5 = (paspobr['paso'] == 5)
paspobr['Poblacion'][cambior5] = 0
# toma valores de poblacion 0 cuando las fases sean distintas a cuarentena
# Out:
# <ipython-input-11-e908d73bab1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspobr['Poblacion'][cambior2] = 0
# <ipython-input-11-e908d73bab1f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspobr['Poblacion'][cambior3] = 0
# <ipython-input-11-e908d73bab1f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspobr['Poblacion'][cambior4] = 0
# <ipython-input-11-e908d73bab1f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paspobr['Poblacion'][cambior5] = 0

# %%
paspob=paspob.sort_values(by='fecha', ascending=True)  
paspob
# orden de las fechas de mas antigua a mas actual
# Out:
#                     Region  Codigo region            Comuna  Codigo comuna  \
# 0       Arica y Parinacota             15             Arica          15101
# 118592           Araucanía              9        Curacautin           9203
# 118156           Araucanía              9             Cunco           9103
# 117720           Araucanía              9        Collipulli           9202
# 6540           Antofagasta              2            Calama           2201
# ...                    ...            ...               ...            ...
# 113795              Biobío              8     Santa Barbara           8311
# 114231              Biobío              8       Santa Juana           8109
# 114667              Biobío              8        Talcahuano           8110
# 83711                Maule              7            Parral           7404
# 168295          Magallanes             12  Torres del Paine          12402
#
#         Poblacion  codigo_region   region_residencia comuna_residencia   zona  \
# 0               0             15  Arica y Parinacota             Arica  Rural
# 118592          0              9        La Araucanía        Curacautín  Rural
# 118156          0              9        La Araucanía             Cunco  Total
# 117720          0              9        La Araucanía        Collipulli  Total
# 6540       190336              2         Antofagasta            Calama  Total
# ...           ...            ...                 ...               ...    ...
# 113795          0              8              Biobío     Santa Bárbara  Total
# 114231          0              8              Biobío       Santa Juana  Total
# 114667          0              8              Biobío        Talcahuano  Total
# 83711           0              7               Maule            Parral  Total
# 168295          0             12          Magallanes  Torres del Paine  Total
#
#              fecha  paso
# 0       2020-07-28     3
# 118592  2020-07-28     4
# 118156  2020-07-28     4
# 117720  2020-07-28     4
# 6540    2020-07-28     1
# ...            ...   ...
# 113795  2021-10-06     4
# 114231  2021-10-06     4
# 114667  2021-10-06     4
# 83711   2021-10-06     3
# 168295  2021-10-06     5
#
# [168296 rows x 11 columns]

# %%
# Como se desconoce como se distribuye la poblacion en las distintas regiones del pais (fechas donde se toma el area rural y/o urbana y/o total),
# se estima que las fechas donde aparece rural y urbana la poblacion se duplicara.

# %%
paspob.drop('paso', axis=1, inplace=True)
paspob.drop('Comuna', axis=1, inplace=True)
paspob.drop('Codigo comuna', axis=1, inplace=True)
paspob.drop('codigo_region', axis=1, inplace=True)
paspob.drop('Codigo region', axis=1, inplace=True)
# lo que se pretende es que el programa sume las poblaciones por comuna cuando estan en cuarentena, no que sume los otros parametros

# %%
paspobr.drop('paso', axis=1, inplace=True)
paspobr.drop('Comuna', axis=1, inplace=True)
paspobr.drop('Codigo comuna', axis=1, inplace=True)
paspobr.drop('Region', axis=1, inplace=True)
paspobr.drop('Codigo region', axis=1, inplace=True)
paspobr.drop('zona', axis=1, inplace=True)
paspobr.drop('comuna_residencia', axis=1, inplace=True)
paspobr.drop('region_residencia', axis=1, inplace=True)

# %%
t=paspob.groupby(['fecha']).sum() 
t
# total de poblacion en cuarentena para cada fecha a nivel pais
# Out:
#             Poblacion
# fecha
# 2020-07-28    9833441
# 2020-07-29   10609230
# 2020-07-30   10609230
# 2020-07-31   10609230
# 2020-08-01   10609230
# ...               ...
# 2021-10-02          0
# 2021-10-03          0
# 2021-10-04          0
# 2021-10-05          0
# 2021-10-06          0
#
# [436 rows x 1 columns]

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=t)
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
t.loc[t['Poblacion'] == t.max()[0]]
# con la funcion loc obtengo las fechas donde el numero de personas en cuarentena en todo el pais alcanzo su valor maximo,
# el que fue de 19.191.466 personas en las fechas 17 y 18 Abril del año 2021.
# Out:
#             Poblacion
# fecha
# 2021-04-17   19191466
# 2021-04-18   19191466

# %%
paspobr1=paspobr[(paspobr['codigo_region']==1)]
paspobr2=paspobr[(paspobr['codigo_region']==2)]
paspobr3=paspobr[(paspobr['codigo_region']==3)]
paspobr4=paspobr[(paspobr['codigo_region']==4)]
paspobr5=paspobr[(paspobr['codigo_region']==5)]
paspobr6=paspobr[(paspobr['codigo_region']==6)]
paspobr7=paspobr[(paspobr['codigo_region']==7)]
paspobr8=paspobr[(paspobr['codigo_region']==8)]
paspobr9=paspobr[(paspobr['codigo_region']==9)]
paspobr10=paspobr[(paspobr['codigo_region']==10)]
paspobr11=paspobr[(paspobr['codigo_region']==11)]
paspobr12=paspobr[(paspobr['codigo_region']==12)]
paspobr13=paspobr[(paspobr['codigo_region']==13)]
paspobr14=paspobr[(paspobr['codigo_region']==14)]
paspobr15=paspobr[(paspobr['codigo_region']==15)]
paspobr16=paspobr[(paspobr['codigo_region']==16)]
# poblacion y fechas separadas por region

# %%
paspobr1.drop('codigo_region', axis=1, inplace=True)
paspobr2.drop('codigo_region', axis=1, inplace=True)
paspobr3.drop('codigo_region', axis=1, inplace=True)
paspobr4.drop('codigo_region', axis=1, inplace=True)
paspobr5.drop('codigo_region', axis=1, inplace=True)
paspobr6.drop('codigo_region', axis=1, inplace=True)
paspobr7.drop('codigo_region', axis=1, inplace=True)
paspobr8.drop('codigo_region', axis=1, inplace=True)
paspobr9.drop('codigo_region', axis=1, inplace=True)
paspobr10.drop('codigo_region', axis=1, inplace=True)
paspobr11.drop('codigo_region', axis=1, inplace=True)
paspobr12.drop('codigo_region', axis=1, inplace=True)
paspobr13.drop('codigo_region', axis=1, inplace=True)
paspobr14.drop('codigo_region', axis=1, inplace=True)
paspobr15.drop('codigo_region', axis=1, inplace=True)
paspobr16.drop('codigo_region', axis=1, inplace=True)
# Out:
# C:\Users\juanc\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr1)
# region 1: tarapaca
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr2)
# region 2: antofagasta
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr3)
# region 3: atacama
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr4)
# region 4: coquimbo
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr5)
# region 5: valparaiso
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr6)
# region 6: ohiggins
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr7)
# region 7: el maule
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr8)
# region 8: el bio bio
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr9)
# region 9: la araucania
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr10)
 # region 10: los lagos
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr11)
# region 11: aysen
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr12)
#region 12: magallanes y antartica chilena
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr13)
# region 13: metropolitana de santiago
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr14)
# region 14: los rios
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr15)
# region 15: arica y parinacota
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
sbn.lineplot(x='fecha', y='Poblacion', data=paspobr16)
# region 16: ñuble
# Out:
# <AxesSubplot:xlabel='fecha', ylabel='Poblacion'>

# %%
r1=paspobr1.groupby(['fecha']).sum()
r2=paspobr2.groupby(['fecha']).sum() 
r3=paspobr3.groupby(['fecha']).sum() 
r4=paspobr4.groupby(['fecha']).sum() 
r5=paspobr5.groupby(['fecha']).sum() 
r6=paspobr6.groupby(['fecha']).sum() 
r7=paspobr7.groupby(['fecha']).sum() 
r8=paspobr8.groupby(['fecha']).sum() 
r9=paspobr9.groupby(['fecha']).sum() 
r10=paspobr10.groupby(['fecha']).sum() 
r11=paspobr11.groupby(['fecha']).sum() 
r12=paspobr12.groupby(['fecha']).sum() 
r13=paspobr13.groupby(['fecha']).sum() 
r14=paspobr14.groupby(['fecha']).sum() 
r15=paspobr15.groupby(['fecha']).sum() 
r16=paspobr16.groupby(['fecha']).sum()

# %%
r1
# Out:
#             Poblacion
# fecha
# 2020-07-28     370857
# 2020-07-29     370857
# 2020-07-30     370857
# 2020-07-31     370857
# 2020-08-01     370857
# ...               ...
# 2021-10-02          0
# 2021-10-03          0
# 2021-10-04          0
# 2021-10-05          0
# 2021-10-06          0
#
# [436 rows x 1 columns]

# %%
r1.loc[r1['Poblacion'] == r1.max()[0]]
# R1 tarapaca
# con esto, se obtienen todos los dias donde la region tuvo el maximo valor de personas en cuarentena para cada region
# Out:
#             Poblacion
# fecha
# 2021-01-28     391252
# 2021-01-29     391252
# 2021-01-30     391252
# 2021-01-31     391252
# 2021-02-01     391252
# 2021-02-02     391252
# 2021-02-03     391252
# 2021-02-04     391252
# 2021-02-05     391252
# 2021-02-06     391252
# 2021-02-07     391252
# 2021-02-08     391252
# 2021-02-09     391252
# 2021-02-10     391252

# %%
r2.loc[r2['Poblacion'] == r2.max()[0]]
# R2 antofagasta
# Out:
#             Poblacion
# fecha
# 2021-04-10    1055443
# 2021-04-11    1055443
# 2021-04-12    1055443
# 2021-04-13    1055443
# 2021-04-14    1055443

# %%
r3.loc[r3['Poblacion'] == r3.max()[0]]
# R3 atacama
# Out:
#             Poblacion
# fecha
# 2021-04-15     275723
# 2021-04-16     275723
# 2021-04-17     275723
# 2021-04-18     275723
# 2021-04-19     275723
# 2021-04-20     275723
# 2021-04-21     275723
# 2021-04-22     275723
# 2021-04-23     275723
# 2021-04-24     275723
# 2021-04-25     275723
# 2021-04-26     275723
# 2021-04-27     275723
# 2021-04-28     275723

# %%
r4.loc[r4['Poblacion'] == r4.max()[0]]
# R4 coquimbo
# Out:
#             Poblacion
# fecha
# 2021-04-03     793772
# 2021-04-04     793772
# 2021-04-05     793772
# 2021-04-06     793772
# 2021-04-07     793772

# %%
r5.loc[r5['Poblacion'] == r5.max()[0]]
# R5 valparaiso
# Out:
#             Poblacion
# fecha
# 2021-04-15    1875007
# 2021-04-16    1875007
# 2021-04-17    1875007
# 2021-04-18    1875007
# 2021-04-19    1875007
# 2021-04-20    1875007
# 2021-04-21    1875007
# 2021-04-22    1875007
# 2021-04-23    1875007
# 2021-04-24    1875007
# 2021-04-25    1875007

# %%
r6.loc[r6['Poblacion'] == r6.max()[0]]
# R6 ohiggins
# Out:
#             Poblacion
# fecha
# 2021-04-10     845196
# 2021-04-11     845196
# 2021-04-12     845196
# 2021-04-13     845196
# 2021-04-14     845196

# %%
r7.loc[r7['Poblacion'] == r7.max()[0]]
# R7 el maule
# Out:
#             Poblacion
# fecha
# 2021-04-17    1523404
# 2021-04-18    1523404
# 2021-04-19    1523404
# 2021-04-20    1523404
# 2021-04-21    1523404
# 2021-04-22    1523404
# 2021-04-23    1523404
# 2021-04-24    1523404
# 2021-04-25    1523404

# %%
r8.loc[r8['Poblacion'] == r8.max()[0]]
# R8 el bio bio
# Out:
#             Poblacion
# fecha
# 2021-01-23    1741315
# 2021-01-24    1741315

# %%
r9.loc[r9['Poblacion'] == r9.max()[0]]
# R9 la araucania
# Out:
#             Poblacion
# fecha
# 2021-04-03    1053231
# 2021-04-04    1053231
# 2021-04-05    1053231
# 2021-04-06    1053231
# 2021-04-07    1053231

# %%
r10.loc[r10['Poblacion'] == r10.max()[0]]
# R10 los lagos
# Out:
#             Poblacion
# fecha
# 2021-02-06     960744
# 2021-02-07     960744
# 2021-02-08     960744
# 2021-02-09     960744
# 2021-02-10     960744
# 2021-02-11     960744
# 2021-02-12     960744
# 2021-02-13     960744
# 2021-02-14     960744
# 2021-02-15     960744

# %%
r11.loc[r11['Poblacion'] == r11.max()[0]]
# R11 aysen
# Out:
#             Poblacion
# fecha
# 2021-06-10     213496
# 2021-06-11     213496
# 2021-06-12     213496
# 2021-06-13     213496
# 2021-06-14     213496
# 2021-06-15     213496
# 2021-06-16     213496
# 2021-06-17     213496
# 2021-06-18     213496
# 2021-06-19     213496
# 2021-06-20     213496
# 2021-06-21     213496
# 2021-06-22     213496
# 2021-06-23     213496
# 2021-06-24     213496
# 2021-06-25     213496
# 2021-06-26     213496
# 2021-06-27     213496
# 2021-06-28     213496
# 2021-06-29     213496
# 2021-06-30     213496
# 2021-07-01     213496
# 2021-07-02     213496
# 2021-07-03     213496
# 2021-07-04     213496

# %%
r12.loc[r12['Poblacion'] == r12.max()[0]]
# R12 magallanes y antartica chilena
# Out:
#             Poblacion
# fecha
# 2020-09-11     173089
# 2020-09-12     173089
# 2020-09-13     173089
# 2020-09-14     173089
# 2020-09-15     173089
# ...               ...
# 2021-05-26     173089
# 2021-05-27     173089
# 2021-05-28     173089
# 2021-05-29     173089
# 2021-05-30     173089
#
# [94 rows x 1 columns]

# %%
r13.loc[r13['Poblacion'] == r13.max()[0]]
# R13 metropolitana de santiago
# Out:
#             Poblacion
# fecha
# 2021-03-27    8321758
# 2021-03-28    8321758
# 2021-03-29    8321758
# 2021-03-30    8321758
# 2021-03-31    8321758
# 2021-04-01    8321758
# 2021-04-02    8321758
# 2021-04-03    8321758
# 2021-04-04    8321758
# 2021-04-05    8321758
# 2021-04-06    8321758
# 2021-04-07    8321758
# 2021-04-08    8321758
# 2021-04-09    8321758
# 2021-04-10    8321758
# 2021-04-11    8321758
# 2021-04-12    8321758
# 2021-04-13    8321758
# 2021-04-14    8321758
# 2021-04-15    8321758
# 2021-04-16    8321758
# 2021-04-17    8321758
# 2021-04-18    8321758
# 2021-04-19    8321758
# 2021-04-20    8321758
# 2021-04-21    8321758
# 2021-04-22    8321758
# 2021-04-23    8321758
# 2021-04-24    8321758
# 2021-04-25    8321758
# 2021-04-26    8321758
# 2021-04-27    8321758
# 2021-04-28    8321758
# 2021-06-12    8321758
# 2021-06-13    8321758
# 2021-06-14    8321758
# 2021-06-15    8321758
# 2021-06-16    8321758
# 2021-06-17    8321758
# 2021-06-18    8321758
# 2021-06-19    8321758
# 2021-06-20    8321758
# 2021-06-21    8321758
# 2021-06-22    8321758
# 2021-06-23    8321758

# %%
r14.loc[r14['Poblacion'] == r14.max()[0]]
# R14 los rios
# Out:
#             Poblacion
# fecha
# 2021-03-11     441826
# 2021-03-12     441826
# 2021-03-13     441826
# 2021-03-14     441826
# 2021-03-15     441826
# 2021-03-16     441826
# 2021-03-17     441826
# 2021-03-18     441826
# 2021-03-19     441826
# 2021-03-20     441826
# 2021-03-21     441826
# 2021-03-22     441826
# 2021-03-23     441826
# 2021-03-24     441826
# 2021-03-25     441826
# 2021-03-26     441826
# 2021-03-27     441826
# 2021-03-28     441826
# 2021-03-29     441826
# 2021-03-30     441826
# 2021-03-31     441826
# 2021-04-01     441826
# 2021-04-02     441826
# 2021-04-03     441826
# 2021-04-04     441826
# 2021-04-05     441826
# 2021-04-06     441826
# 2021-04-07     441826
# 2021-04-08     441826
# 2021-04-09     441826
# 2021-04-10     441826
# 2021-04-11     441826
# 2021-04-12     441826
# 2021-04-13     441826
# 2021-04-14     441826
# 2021-04-15     441826
# 2021-04-16     441826
# 2021-04-17     441826
# 2021-04-18     441826

# %%
r15.loc[r15['Poblacion'] == r15.max()[0]]
# R15 arica y parinacota
# Out:
#             Poblacion
# fecha
# 2021-02-04     495104
# 2021-02-05     495104
# 2021-02-06     495104
# 2021-02-07     495104
# 2021-02-08     495104
# ...               ...
# 2021-06-12     495104
# 2021-06-13     495104
# 2021-06-14     495104
# 2021-06-15     495104
# 2021-06-16     495104
#
# [81 rows x 1 columns]

# %%
r16.loc[r16['Poblacion'] == r16.max()[0]]
# R16 ñuble
# Out:
#             Poblacion
# fecha
# 2021-04-10     671615
# 2021-04-11     671615
# 2021-04-12     671615
# 2021-04-13     671615
# 2021-04-14     671615
# 2021-04-15     671615
# 2021-04-16     671615
# 2021-04-17     671615
# 2021-04-18     671615
